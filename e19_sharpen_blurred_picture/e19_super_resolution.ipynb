# %% [markdown]
# # Super Resolution
#
# 저해상도 영상을 고해상도 영상으로 변환하는 작업
#
# 보간법(interpolation)을 활용하는게 기본

# %%
# bilinear interpolation(2차원 상 선형 보간법 예시)
from skimage import data
import matplotlib.pyplot as plt

hr_image = data.chelsea() # skimage에서 제공하는 예제 이미지를 불러옵니다.
hr_shape = hr_image.shape[:2]

print(hr_image.shape) # 이미지의 크기를 출력합니다.

plt.figure(figsize=(6,3))
plt.imshow(hr_image)
# Out:
# (300, 451, 3)

# %% [markdown]
# 고양이 이미지 크기 (세로 픽셀 수 X 가로 픽셀 수 X 채널 수) [300x451x3]
#
# 저 해상도로 낮춘 뒤 다시 super resolution 사용
#
# `opencv` 의 `resize()`활용

# %%
import cv2
lr_image = cv2.resize(hr_image, dsize=(150,100)) # (가로 픽셀 수, 세로 픽셀 수)

print(lr_image.shape)

plt.figure(figsize=(3,1))
plt.imshow(lr_image)
# Out:
# (100, 150, 3)

# %%
bilinear_image = cv2.resize(
    lr_image, 
    dsize=(451, 300), # (가로 픽셀 수, 세로 픽셀 수) 
    interpolation=cv2.INTER_LINEAR # bilinear interpolation 적용
)

bicubic_image = cv2.resize(
    lr_image, 
    dsize=(451, 300), # (가로 픽셀 수, 세로 픽셀 수)
    interpolation=cv2.INTER_CUBIC # bicubic interpolation 적용
)

images = [bilinear_image, bicubic_image, hr_image]
titles = ["Bilinear", "Bicubic", "Original"]

plt.figure(figsize=(16,3))
for i, (image, title) in enumerate(zip(images, titles)):
    plt.subplot(1,3,i+1)
    plt.imshow(image)
    plt.title(title, fontsize=20)

# %%
# 특정 영역을 잘라낼 함수를 정의합니다.
def crop(image, left_top, x=50, y=100):
    return image[left_top[0]:(left_top[0]+x), left_top[1]:(left_top[1]+y), :]


# 잘라낼 영역의 좌표를 정의합니다.
left_tops = [(220,200)] *3 + [(90,120)] *3 + [(30,200)] *3

plt.figure(figsize=(16,10))
for i, (image, left_top, title) in enumerate(zip(images*3, left_tops, titles*3)):
    plt.subplot(3,3,i+1)
    plt.imshow(crop(image, left_top))
    plt.title(title, fontsize=20)

# %% [markdown]
# ## Deep Learning 을 이용한 Super Resolution

# %% [markdown]
# ![image.png](1.png)
# ![image-2.png](2.png)
# ![image-3.png](3.png)
# ![image-4.png](4.png)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

# 데이터를 불러옵니다.
train, valid = tfds.load(
    "div2k/bicubic_x4", 
    split=["train","validation"],
    as_supervised=True
)

# 시각화를 위해 한 개의 데이터만 선택합니다.
for i, (lr, hr) in enumerate(valid):
    if i == 6: break
    
# 저해상도 이미지를 고해상도 이미지 크기로 bicubic interpolation 합니다.  
hr, lr = np.array(hr), np.array(lr)
bicubic_hr = cv2.resize(
    lr, 
    dsize=(hr.shape[1], hr.shape[0]), # 고해상도 이미지 크기로 설정 , 가로, 세로 순서
    interpolation=cv2.INTER_CUBIC # bicubic 설정
)

# 저해상도 및 고해상도 이미지를 시각화 합니다.
plt.figure(figsize=(20,10))
plt.subplot(1,2,1); plt.imshow(bicubic_hr)
plt.subplot(1,2,2); plt.imshow(hr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py in normalize_element(element)
#      92       try:
# ---> 93         spec = type_spec_from_value(t, use_fallback=False)
#      94       except TypeError:
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py in type_spec_from_value(element, use_fallback)
#     464
# --> 465   raise TypeError("Could not build a TypeSpec for %r with type %s" %
#     466                   (element, type(element).__name__))
#
# TypeError: Could not build a TypeSpec for ['/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00000-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00001-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00002-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00003-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00004-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00005-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00006-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00007-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00008-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00009-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00010-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00011-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00012-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00013-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00014-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00015-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00016-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00017-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00018-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00019-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00020-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00021-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00022-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00023-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00024-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00025-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00026-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00027-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00028-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00029-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00030-of-00032', '/home/aiffel0042/tensorflow_datasets/div2k/bicubic_x4/2.0.0/div2k-train.tfrecord-00031-of-00032'] with type list
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-6-9d69d2e43ac5> in <module>
#       5
#       6 # 데이터를 불러옵니다.
# ----> 7 train, valid = tfds.load(
#       8     "div2k/bicubic_x4",
#       9     split=["train","validation"],
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/load.py in load(name, split, data_dir, batch_size, shuffle_files, download, as_supervised, decoders, read_config, with_info, builder_kwargs, download_and_prepare_kwargs, as_dataset_kwargs, try_gcs)
#     354   as_dataset_kwargs.setdefault("read_config", read_config)
#     355
# --> 356   ds = dbuilder.as_dataset(**as_dataset_kwargs)
#     357   if with_info:
#     358     return ds, dbuilder.info
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py in as_dataset(self, split, batch_size, shuffle_files, decoders, read_config, as_supervised)
#     532         as_supervised=as_supervised,
#     533     )
# --> 534     datasets = utils.map_nested(build_single_dataset, split, map_tuple=True)
#     535     return datasets
#     536
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_tuple)
#     179       types_.append(tuple)
#     180     if isinstance(data_struct, tuple(types_)):
# --> 181       mapped = [map_nested(function, v, dict_only, map_tuple)
#     182                 for v in data_struct]
#     183       if isinstance(data_struct, list):
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/utils/py_utils.py in <listcomp>(.0)
#     179       types_.append(tuple)
#     180     if isinstance(data_struct, tuple(types_)):
# --> 181       mapped = [map_nested(function, v, dict_only, map_tuple)
#     182                 for v in data_struct]
#     183       if isinstance(data_struct, list):
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_tuple)
#     186         return tuple(mapped)
#     187   # Singleton
# --> 188   return function(data_struct)
#     189
#     190
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py in _build_single_dataset(self, split, shuffle_files, batch_size, decoders, read_config, as_supervised)
#     550
#     551     # Build base dataset
# --> 552     ds = self._as_dataset(
#     553         split=split,
#     554         shuffle_files=shuffle_files,
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/dataset_builder.py in _as_dataset(self, split, decoders, read_config, shuffle_files)
#     873       read_config=None,
#     874       shuffle_files=False):
# --> 875     ds = self._tfrecords_reader.read(
#     876         name=self.name,
#     877         instructions=split,
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/tfrecords_reader.py in read(self, name, instructions, split_infos, read_config, shuffle_files)
#     276       )
#     277
# --> 278     return tf.nest.map_structure(_read_instruction_to_ds, instructions)
#     279
#     280   def read_files(
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/tfrecords_reader.py in _read_instruction_to_ds(instruction)
#     270     def _read_instruction_to_ds(instruction):
#     271       file_instructions = make_file_instructions(name, split_infos, instruction)
# --> 272       return self.read_files(
#     273           file_instructions,
#     274           read_config=read_config,
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/tfrecords_reader.py in read_files(self, file_instructions, read_config, shuffle_files)
#     306         for f in file_instructions
#     307     ]
# --> 308     ds = _read_files(
#     309         file_instructions=file_instructions,
#     310         read_config=read_config,
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow_datasets/core/tfrecords_reader.py in _read_files(file_instructions, parse_fn, read_config, shuffle_files)
#     171   block_length = read_config.interleave_block_length
#     172
# --> 173   instruction_ds = tf.data.Dataset.from_tensor_slices(tensor_inputs)
#     174
#     175   # On distributed environement, we can shard per-file if a
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors)
#     680       Dataset: A `Dataset`.
#     681     """
# --> 682     return TensorSliceDataset(tensors)
#     683
#     684   class _GeneratorState(object):
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, element)
#    2999   def __init__(self, element):
#    3000     """See `Dataset.from_tensor_slices()` for details."""
# -> 3001     element = structure.normalize_element(element)
#    3002     batched_spec = structure.type_spec_from_value(element)
#    3003     self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/data/util/structure.py in normalize_element(element)
#      96         # the value. As a fallback try converting the value to a tensor.
#      97         normalized_components.append(
# ---> 98             ops.convert_to_tensor(t, name="component_%d" % i))
#      99       else:
#     100         if isinstance(spec, sparse_tensor.SparseTensorSpec):
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1497
#    1498     if ret is None:
# -> 1499       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1500
#    1501     if ret is NotImplemented:
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     336                                          as_ref=False):
#     337   _ = as_ref
# --> 338   return constant(v, dtype=dtype, name=name)
#     339
#     340
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     261     ValueError: if called on a symbolic tensor.
#     262   """
# --> 263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     264                         allow_broadcast=True)
#     265
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273       with trace.Trace("tf.constant"):
#     274         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     276
#     277   g = ops.get_default_graph()
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     298 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     299   """Implementation of eager constant."""
# --> 300   t = convert_to_eager_tensor(value, ctx, dtype)
#     301   if shape is None:
#     302     return t
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      95     except AttributeError:
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ---> 97   ctx.ensure_initialized()
#      98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#
# ~/anaconda3/envs/aiffel/lib/python3.8/site-packages/tensorflow/python/eager/context.py in ensure_initialized(self)
#     537         if self._use_tfrt is not None:
#     538           pywrap_tfe.TFE_ContextOptionsSetTfrt(opts, self._use_tfrt)
# --> 539         context_handle = pywrap_tfe.TFE_NewContext(opts)
#     540       finally:
#     541         pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# InternalError: CUDA runtime implicit initialization on GPU:0 failed. Status: out of memory

# %%
# 이미지의 특정 부분을 잘라내는 함수를 정의합니다.
def crop(image, left_top, x=200, y=200):
    return image[left_top[0]:(left_top[0]+x), left_top[1]:(left_top[1]+y), :]

# interpolation된 이미지와 고해상도 이미지의 동일한 부분을 각각 잘라냅니다.
left_top = (400, 500)
crop_bicubic_hr = crop(bicubic_hr, left_top)
crop_hr = crop(hr, left_top)

# 잘라낸 부분을 시각화 합니다.
plt.figure(figsize=(15,25))
plt.subplot(1,2,1); plt.imshow(crop_bicubic_hr); plt.title("Bicubic", fontsize=30)
plt.subplot(1,2,2); plt.imshow(crop_hr); plt.title("HR", fontsize=30)

# %%
import tensorflow as tf

def preprocessing(lr, hr):
    # 이미지의 크기가 크므로 (96,96,3) 크기로 임의 영역을 잘라내어 사용합니다.
    hr = tf.image.random_crop(hr, size=[96, 96, 3])
    hr = tf.cast(hr, tf.float32) / 255.
    
    # 잘라낸 고해상도 이미지의 가로, 세로 픽셀 수를 1/4배로 줄였다가
    # interpolation을 이용해 다시 원래 크기로 되돌립니다.
    # 이렇게 만든 저해상도 이미지를 입력으로 사용합니다.
    lr = tf.image.resize(hr, [96//4, 96//4], "bicubic")
    lr = tf.image.resize(lr, [96, 96], "bicubic")
    return lr, hr

train = train.map(preprocessing).shuffle(buffer_size=10).batch(16)
valid = valid.map(preprocessing).batch(16)
print("✅")

# %%
from tensorflow.keras import layers, Sequential

# 3개의 convolutional layer를 갖는 Sequential 모델을 구성합니다.
srcnn = Sequential()
# 9x9 크기의 필터를 128개 사용합니다.
srcnn.add(layers.Conv2D(128, 9, padding="same", input_shape=(None, None, 3)))
srcnn.add(layers.ReLU())
# 5x5 크기의 필터를 64개 사용합니다.
srcnn.add(layers.Conv2D(64, 5, padding="same"))
srcnn.add(layers.ReLU())
# 5x5 크기의 필터를 64개 사용합니다.
srcnn.add(layers.Conv2D(3, 5, padding="same"))

srcnn.summary()

# %%
srcnn.compile(
    optimizer="adam", 
    loss="mse"
)

srcnn.fit(train, validation_data=valid, epochs=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cc7ffdd9b1d5> in <module>
# ----> 1 srcnn.compile(
#       2     optimizer="adam",
#       3     loss="mse"
#       4 )
#       5
#
# NameError: name 'srcnn' is not defined

# %%
import tensorflow as tf
import os

model_file = os.getenv('HOME')+'/project/AIFFEL_Study/e19_sharpen_blurred_picture/srcnn.h5'
srcnn = tf.keras.models.load_model(model_file)

# %%
def apply_srcnn(image):
    sr = srcnn.predict(image[np.newaxis, ...]/255.)
    sr[sr > 1] = 1
    sr[sr < 0] = 0
    sr *= 255.
    return np.array(sr[0].astype(np.uint8))

srcnn_hr = apply_srcnn(bicubic_hr)
plt.imshow(srcnn_hr)

# %%
# 자세히 시각화 하기 위해 3개 영역을 잘라냅니다.
# 아래는 잘라낸 부분의 좌상단 좌표 3개 입니다.
left_tops = [(400,500), (300,1200), (0,1000)]

images = []
for left_top in left_tops:
    img1 = crop(bicubic_hr, left_top, 200, 200)
    img2 = crop(srcnn_hr , left_top, 200, 200)
    img3 = crop(hr, left_top, 200, 200)
    images.extend([img1, img2, img3])

labels = ["Bicubic", "SRCNN", "HR"] * 3

plt.figure(figsize=(18,18))
for i in range(9):
    plt.subplot(3,3,i+1) 
    plt.imshow(images[i])
    plt.title(labels[i], fontsize=30)
