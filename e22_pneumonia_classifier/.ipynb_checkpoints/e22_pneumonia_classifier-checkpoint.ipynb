# %% [markdown]
# # 폐렴 분류기

# %% [markdown]
# ## import

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /home/aiffel0042/aiffel

# %% [markdown]
# ## 데이터 가져오기

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ## 데이터 분할

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1107
# Pneumonia images count in training set: 3078

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['NORMAL' 'PNEUMONIA']

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds_base = prepare_for_training(train_ds)
val_ds_base = prepare_for_training(val_ds)

# %% [markdown]
# ## Augmentation

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    
    return image,label

def prepare_for_training_aug(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_aug_ds = prepare_for_training_aug(train_ds)
val_aug_ds = prepare_for_training_aug(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds_base))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %%
image_aug_batch, label_aug_batch = next(iter(train_aug_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    print(image_batch.shape)
    print(label_batch.shape)
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_aug_batch.numpy(), label_aug_batch.numpy())
# Out:
# (16, 180, 180, 3)
# (16,)

# %% [markdown]
# ## Model

# %%
def conv_block(layer, filters):
    x = tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same')(layer)
    x = tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPool2D()(x)

    return x

# %%
def dense_block(layer, units, dropout_rate=0.5, dropout=True):
    x = tf.keras.layers.Dense(units, activation='relu')(layer)
    x = tf.keras.layers.BatchNormalization()(x)
    if dropout:
        x = tf.keras.layers.Dropout(dropout_rate)(x)
    
    return x

# %%
def build_model(dropout=True,drophalf=False):
    input_layer = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
    
    x = tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same')(input_layer)
    x = tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPool2D()(x)
    
    x = conv_block(x, 32)
    x = conv_block(x, 64)
    
    x = conv_block(x, 128)
    if dropout:
        if drophalf:
            x = tf.keras.layers.Dropout(0.2)(x)
        else:
            x = tf.keras.layers.Dropout(0.5)(x)
    
    x = conv_block(x, 256)
    if dropout:
        if drophalf:
            x = tf.keras.layers.Dropout(0.2)(x)
        else:
            x = tf.keras.layers.Dropout(0.5)(x)
    
    x = tf.keras.layers.Flatten()(x)
    x = dense_block(x, 512, 0.7)
    x = dense_block(x, 128, 0.5)
    x = dense_block(x, 64, 0.3)
    
    output = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs=input_layer, outputs=output)
    
    return model

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.89
# Weight for class 1: 0.68

# %% [markdown]
# ## Training

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds_base,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_base,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
#   2/261 [..............................] - ETA: 8s - loss: 0.9152 - accuracy: 0.5312 - precision: 0.7692 - recall: 0.4545WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0194s vs `on_train_batch_end` time: 0.0412s). Check your callbacks.
# 261/261 [==============================] - 22s 85ms/step - loss: 0.5297 - accuracy: 0.7325 - precision: 0.9122 - recall: 0.7040 - val_loss: 0.5425 - val_accuracy: 0.7683 - val_precision: 0.7683 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.3386 - accuracy: 0.8546 - precision: 0.9536 - recall: 0.8434 - val_loss: 0.6392 - val_accuracy: 0.7683 - val_precision: 0.7683 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.2745 - accuracy: 0.8937 - precision: 0.9673 - recall: 0.8853 - val_loss: 0.2701 - val_accuracy: 0.8519 - val_precision: 0.8386 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.2422 - accuracy: 0.9030 - precision: 0.9704 - recall: 0.8956 - val_loss: 0.1601 - val_accuracy: 0.9394 - val_precision: 0.9792 - val_recall: 0.9413
# Epoch 5/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.2065 - accuracy: 0.9167 - precision: 0.9732 - recall: 0.9118 - val_loss: 0.1152 - val_accuracy: 0.9654 - val_precision: 0.9775 - val_recall: 0.9775
# Epoch 6/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1969 - accuracy: 0.9265 - precision: 0.9759 - recall: 0.9227 - val_loss: 0.6634 - val_accuracy: 0.7423 - val_precision: 1.0000 - val_recall: 0.6650
# Epoch 7/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1846 - accuracy: 0.9291 - precision: 0.9777 - recall: 0.9250 - val_loss: 0.5060 - val_accuracy: 0.7962 - val_precision: 1.0000 - val_recall: 0.7347
# Epoch 8/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.1681 - accuracy: 0.9339 - precision: 0.9797 - recall: 0.9292 - val_loss: 0.1125 - val_accuracy: 0.9500 - val_precision: 0.9934 - val_recall: 0.9411
# Epoch 9/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1497 - accuracy: 0.9440 - precision: 0.9833 - recall: 0.9398 - val_loss: 0.2380 - val_accuracy: 0.9048 - val_precision: 1.0000 - val_recall: 0.8764
# Epoch 10/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1304 - accuracy: 0.9516 - precision: 0.9861 - recall: 0.9475 - val_loss: 0.1071 - val_accuracy: 0.9606 - val_precision: 0.9987 - val_recall: 0.9501
# Epoch 11/25
# 261/261 [==============================] - 22s 82ms/step - loss: 0.1384 - accuracy: 0.9492 - precision: 0.9838 - recall: 0.9466 - val_loss: 0.5504 - val_accuracy: 0.8587 - val_precision: 0.8448 - val_recall: 1.0000
# Epoch 12/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1255 - accuracy: 0.9497 - precision: 0.9835 - recall: 0.9477 - val_loss: 0.4507 - val_accuracy: 0.8096 - val_precision: 1.0000 - val_recall: 0.7519
# Epoch 13/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1420 - accuracy: 0.9459 - precision: 0.9850 - recall: 0.9406 - val_loss: 0.1043 - val_accuracy: 0.9577 - val_precision: 0.9935 - val_recall: 0.9511
# Epoch 14/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.1261 - accuracy: 0.9492 - precision: 0.9864 - recall: 0.9439 - val_loss: 0.0548 - val_accuracy: 0.9769 - val_precision: 0.9911 - val_recall: 0.9787
# Epoch 15/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1311 - accuracy: 0.9500 - precision: 0.9848 - recall: 0.9467 - val_loss: 0.1471 - val_accuracy: 0.9433 - val_precision: 0.9333 - val_recall: 0.9975
# Epoch 16/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0991 - accuracy: 0.9643 - precision: 0.9906 - recall: 0.9606 - val_loss: 0.0497 - val_accuracy: 0.9827 - val_precision: 0.9937 - val_recall: 0.9837
# Epoch 17/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0909 - accuracy: 0.9672 - precision: 0.9897 - recall: 0.9656 - val_loss: 0.1356 - val_accuracy: 0.9500 - val_precision: 0.9987 - val_recall: 0.9361
# Epoch 18/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0891 - accuracy: 0.9696 - precision: 0.9913 - recall: 0.9670 - val_loss: 0.1824 - val_accuracy: 0.9240 - val_precision: 1.0000 - val_recall: 0.9011
# Epoch 19/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0865 - accuracy: 0.9684 - precision: 0.9894 - recall: 0.9675 - val_loss: 0.0761 - val_accuracy: 0.9692 - val_precision: 0.9961 - val_recall: 0.9638
# Epoch 20/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0876 - accuracy: 0.9653 - precision: 0.9929 - recall: 0.9595 - val_loss: 0.0494 - val_accuracy: 0.9760 - val_precision: 0.9936 - val_recall: 0.9750
# Epoch 21/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0883 - accuracy: 0.9667 - precision: 0.9916 - recall: 0.9630 - val_loss: 0.0637 - val_accuracy: 0.9750 - val_precision: 0.9778 - val_recall: 0.9900
# Epoch 22/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0794 - accuracy: 0.9710 - precision: 0.9930 - recall: 0.9674 - val_loss: 0.0974 - val_accuracy: 0.9644 - val_precision: 0.9987 - val_recall: 0.9549
# Epoch 23/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0782 - accuracy: 0.9703 - precision: 0.9936 - recall: 0.9657 - val_loss: 0.0923 - val_accuracy: 0.9654 - val_precision: 0.9897 - val_recall: 0.9650
# Epoch 24/25
# 261/261 [==============================] - 24s 90ms/step - loss: 0.0796 - accuracy: 0.9732 - precision: 0.9943 - recall: 0.9691 - val_loss: 0.0744 - val_accuracy: 0.9721 - val_precision: 0.9873 - val_recall: 0.9762
# Epoch 25/25
# 261/261 [==============================] - 26s 101ms/step - loss: 0.0690 - accuracy: 0.9746 - precision: 0.9934 - recall: 0.9722 - val_loss: 0.0965 - val_accuracy: 0.9625 - val_precision: 0.9987 - val_recall: 0.9524

# %% [markdown]
# ## augmentation model

# %%
with tf.device('/GPU:0'):
    model_aug = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model_aug.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history_aug = model_aug.fit(
        train_aug_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_aug_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 26s 98ms/step - loss: 0.4649 - accuracy: 0.7761 - precision: 0.9313 - recall: 0.7509 - val_loss: 0.5791 - val_accuracy: 0.7692 - val_precision: 0.7692 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 25s 97ms/step - loss: 0.2868 - accuracy: 0.8898 - precision: 0.9647 - recall: 0.8824 - val_loss: 1.0805 - val_accuracy: 0.7673 - val_precision: 0.7673 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 24s 94ms/step - loss: 0.2132 - accuracy: 0.9155 - precision: 0.9723 - recall: 0.9113 - val_loss: 1.4173 - val_accuracy: 0.7673 - val_precision: 0.7673 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.2284 - accuracy: 0.9104 - precision: 0.9737 - recall: 0.9026 - val_loss: 0.5742 - val_accuracy: 0.7827 - val_precision: 0.9948 - val_recall: 0.7209
# Epoch 5/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.2003 - accuracy: 0.9227 - precision: 0.9764 - recall: 0.9170 - val_loss: 0.5459 - val_accuracy: 0.7990 - val_precision: 0.9983 - val_recall: 0.7397
# Epoch 6/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.1757 - accuracy: 0.9346 - precision: 0.9778 - recall: 0.9323 - val_loss: 0.1428 - val_accuracy: 0.9442 - val_precision: 0.9987 - val_recall: 0.9287
# Epoch 7/25
# 261/261 [==============================] - 24s 93ms/step - loss: 0.1784 - accuracy: 0.9322 - precision: 0.9813 - recall: 0.9253 - val_loss: 0.1022 - val_accuracy: 0.9606 - val_precision: 0.9859 - val_recall: 0.9625
# Epoch 8/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.1557 - accuracy: 0.9399 - precision: 0.9806 - recall: 0.9369 - val_loss: 0.1575 - val_accuracy: 0.9288 - val_precision: 0.9945 - val_recall: 0.9123
# Epoch 9/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1713 - accuracy: 0.9351 - precision: 0.9807 - recall: 0.9298 - val_loss: 0.0858 - val_accuracy: 0.9625 - val_precision: 0.9987 - val_recall: 0.9525
# Epoch 10/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1520 - accuracy: 0.9456 - precision: 0.9840 - recall: 0.9414 - val_loss: 0.1133 - val_accuracy: 0.9500 - val_precision: 0.9857 - val_recall: 0.9487
# Epoch 11/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1647 - accuracy: 0.9346 - precision: 0.9814 - recall: 0.9287 - val_loss: 0.1026 - val_accuracy: 0.9606 - val_precision: 0.9726 - val_recall: 0.9762
# Epoch 12/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1549 - accuracy: 0.9387 - precision: 0.9819 - recall: 0.9340 - val_loss: 0.2647 - val_accuracy: 0.8933 - val_precision: 1.0000 - val_recall: 0.8616
# Epoch 13/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1257 - accuracy: 0.9533 - precision: 0.9868 - recall: 0.9492 - val_loss: 0.2170 - val_accuracy: 0.9010 - val_precision: 1.0000 - val_recall: 0.8712
# Epoch 14/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1409 - accuracy: 0.9468 - precision: 0.9867 - recall: 0.9406 - val_loss: 0.0828 - val_accuracy: 0.9683 - val_precision: 0.9910 - val_recall: 0.9675
# Epoch 15/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1257 - accuracy: 0.9531 - precision: 0.9851 - recall: 0.9502 - val_loss: 0.1206 - val_accuracy: 0.9433 - val_precision: 1.0000 - val_recall: 0.9262
# Epoch 16/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1181 - accuracy: 0.9586 - precision: 0.9885 - recall: 0.9547 - val_loss: 0.2234 - val_accuracy: 0.9173 - val_precision: 1.0000 - val_recall: 0.8922
# Epoch 17/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1057 - accuracy: 0.9552 - precision: 0.9879 - recall: 0.9510 - val_loss: 0.0710 - val_accuracy: 0.9721 - val_precision: 0.9837 - val_recall: 0.9800
# Epoch 18/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1516 - accuracy: 0.9444 - precision: 0.9840 - recall: 0.9398 - val_loss: 0.0636 - val_accuracy: 0.9721 - val_precision: 0.9849 - val_recall: 0.9787
# Epoch 19/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1222 - accuracy: 0.9495 - precision: 0.9880 - recall: 0.9425 - val_loss: 0.1124 - val_accuracy: 0.9558 - val_precision: 0.9510 - val_recall: 0.9937
# Epoch 20/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1232 - accuracy: 0.9557 - precision: 0.9862 - recall: 0.9531 - val_loss: 0.0940 - val_accuracy: 0.9567 - val_precision: 0.9909 - val_recall: 0.9524
# Epoch 21/25
# 261/261 [==============================] - 22s 86ms/step - loss: 0.1139 - accuracy: 0.9574 - precision: 0.9885 - recall: 0.9530 - val_loss: 0.0583 - val_accuracy: 0.9760 - val_precision: 0.9949 - val_recall: 0.9737
# Epoch 22/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1131 - accuracy: 0.9550 - precision: 0.9879 - recall: 0.9507 - val_loss: 0.0639 - val_accuracy: 0.9721 - val_precision: 0.9777 - val_recall: 0.9863
# Epoch 23/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1321 - accuracy: 0.9492 - precision: 0.9857 - recall: 0.9446 - val_loss: 0.8310 - val_accuracy: 0.8346 - val_precision: 0.8269 - val_recall: 0.9925
# Epoch 24/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1189 - accuracy: 0.9509 - precision: 0.9867 - recall: 0.9459 - val_loss: 0.1204 - val_accuracy: 0.9558 - val_precision: 0.9608 - val_recall: 0.9825
# Epoch 25/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0990 - accuracy: 0.9636 - precision: 0.9886 - recall: 0.9615 - val_loss: 0.0617 - val_accuracy: 0.9760 - val_precision: 0.9936 - val_recall: 0.9750

# %% [markdown]
# ## drop out half model

# %%
with tf.device('/GPU:0'):
    model_drop_half = build_model(dropout=True, drophalf=True)

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model_drop_half.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history_drop_half = model_drop_half.fit(
        train_ds_base,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_base,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
#   2/261 [..............................] - ETA: 15s - loss: 0.6669 - accuracy: 0.6250 - precision: 1.0000 - recall: 0.5385WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0275s vs `on_train_batch_end` time: 0.0477s). Check your callbacks.
# 261/261 [==============================] - 23s 89ms/step - loss: 0.3604 - accuracy: 0.8264 - precision: 0.9525 - recall: 0.8039 - val_loss: 0.5972 - val_accuracy: 0.7702 - val_precision: 0.7702 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.2364 - accuracy: 0.9148 - precision: 0.9686 - recall: 0.9137 - val_loss: 1.3802 - val_accuracy: 0.7683 - val_precision: 0.7683 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1938 - accuracy: 0.9270 - precision: 0.9736 - recall: 0.9258 - val_loss: 0.2535 - val_accuracy: 0.8817 - val_precision: 0.8666 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1933 - accuracy: 0.9270 - precision: 0.9749 - recall: 0.9245 - val_loss: 0.0809 - val_accuracy: 0.9683 - val_precision: 0.9706 - val_recall: 0.9888
# Epoch 5/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1608 - accuracy: 0.9413 - precision: 0.9793 - recall: 0.9402 - val_loss: 0.1235 - val_accuracy: 0.9587 - val_precision: 0.9948 - val_recall: 0.9512
# Epoch 6/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1451 - accuracy: 0.9490 - precision: 0.9847 - recall: 0.9453 - val_loss: 0.2959 - val_accuracy: 0.9106 - val_precision: 0.9986 - val_recall: 0.8849
# Epoch 7/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1460 - accuracy: 0.9464 - precision: 0.9820 - recall: 0.9442 - val_loss: 0.2196 - val_accuracy: 0.9269 - val_precision: 0.9972 - val_recall: 0.9074
# Epoch 8/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.1322 - accuracy: 0.9507 - precision: 0.9851 - recall: 0.9474 - val_loss: 0.0781 - val_accuracy: 0.9692 - val_precision: 0.9974 - val_recall: 0.9624
# Epoch 9/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1396 - accuracy: 0.9507 - precision: 0.9828 - recall: 0.9495 - val_loss: 0.1058 - val_accuracy: 0.9692 - val_precision: 0.9987 - val_recall: 0.9613
# Epoch 10/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1196 - accuracy: 0.9581 - precision: 0.9885 - recall: 0.9541 - val_loss: 0.2318 - val_accuracy: 0.9154 - val_precision: 1.0000 - val_recall: 0.8897
# Epoch 11/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1092 - accuracy: 0.9617 - precision: 0.9886 - recall: 0.9590 - val_loss: 0.0771 - val_accuracy: 0.9692 - val_precision: 0.9961 - val_recall: 0.9638
# Epoch 12/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1180 - accuracy: 0.9586 - precision: 0.9863 - recall: 0.9571 - val_loss: 0.1462 - val_accuracy: 0.9481 - val_precision: 1.0000 - val_recall: 0.9324
# Epoch 13/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0872 - accuracy: 0.9684 - precision: 0.9936 - recall: 0.9632 - val_loss: 0.1244 - val_accuracy: 0.9606 - val_precision: 0.9922 - val_recall: 0.9561
# Epoch 14/25
# 261/261 [==============================] - 24s 90ms/step - loss: 0.1197 - accuracy: 0.9569 - precision: 0.9888 - recall: 0.9521 - val_loss: 0.0815 - val_accuracy: 0.9654 - val_precision: 0.9987 - val_recall: 0.9562
# Epoch 15/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0962 - accuracy: 0.9638 - precision: 0.9903 - recall: 0.9604 - val_loss: 0.0551 - val_accuracy: 0.9779 - val_precision: 0.9850 - val_recall: 0.9863
# Epoch 16/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0763 - accuracy: 0.9720 - precision: 0.9926 - recall: 0.9690 - val_loss: 0.1105 - val_accuracy: 0.9635 - val_precision: 0.9910 - val_recall: 0.9612
# Epoch 17/25
# 261/261 [==============================] - 24s 94ms/step - loss: 0.0909 - accuracy: 0.9727 - precision: 0.9911 - recall: 0.9718 - val_loss: 0.2669 - val_accuracy: 0.9010 - val_precision: 0.9971 - val_recall: 0.8736
# Epoch 18/25
# 261/261 [==============================] - 24s 93ms/step - loss: 0.1097 - accuracy: 0.9626 - precision: 0.9903 - recall: 0.9587 - val_loss: 0.1928 - val_accuracy: 0.9183 - val_precision: 0.9972 - val_recall: 0.8964
# Epoch 19/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.0800 - accuracy: 0.9701 - precision: 0.9930 - recall: 0.9661 - val_loss: 0.1382 - val_accuracy: 0.9529 - val_precision: 0.9973 - val_recall: 0.9412
# Epoch 20/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0786 - accuracy: 0.9708 - precision: 0.9943 - recall: 0.9657 - val_loss: 0.1109 - val_accuracy: 0.9596 - val_precision: 0.9987 - val_recall: 0.9488
# Epoch 21/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.0699 - accuracy: 0.9732 - precision: 0.9924 - recall: 0.9711 - val_loss: 0.1283 - val_accuracy: 0.9538 - val_precision: 0.9486 - val_recall: 0.9937
# Epoch 22/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0661 - accuracy: 0.9753 - precision: 0.9940 - recall: 0.9722 - val_loss: 0.0612 - val_accuracy: 0.9769 - val_precision: 0.9837 - val_recall: 0.9862
# Epoch 23/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.0498 - accuracy: 0.9825 - precision: 0.9947 - recall: 0.9815 - val_loss: 0.6158 - val_accuracy: 0.7712 - val_precision: 0.9879 - val_recall: 0.7116
# Epoch 24/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.0640 - accuracy: 0.9753 - precision: 0.9943 - recall: 0.9720 - val_loss: 0.0960 - val_accuracy: 0.9635 - val_precision: 0.9823 - val_recall: 0.9700
# Epoch 25/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0602 - accuracy: 0.9792 - precision: 0.9940 - recall: 0.9775 - val_loss: 0.1109 - val_accuracy: 0.9587 - val_precision: 0.9987 - val_recall: 0.9475

# %% [markdown]
# ## except dropout

# %%
with tf.device('/GPU:0'):
    model_no_drop = build_model(dropout=False)

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model_no_drop.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history_no_drop = model_no_drop.fit(
        train_ds_base,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds_base,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
#   2/261 [..............................] - ETA: 14s - loss: 1.0614 - accuracy: 0.5625 - precision: 0.8235 - recall: 0.5600WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0227s vs `on_train_batch_end` time: 0.0491s). Check your callbacks.
# 261/261 [==============================] - 23s 88ms/step - loss: 0.3193 - accuracy: 0.8573 - precision: 0.9686 - recall: 0.8330 - val_loss: 0.5574 - val_accuracy: 0.7702 - val_precision: 0.7702 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1862 - accuracy: 0.9303 - precision: 0.9783 - recall: 0.9258 - val_loss: 0.9726 - val_accuracy: 0.7683 - val_precision: 0.7683 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 22s 82ms/step - loss: 0.1756 - accuracy: 0.9382 - precision: 0.9789 - recall: 0.9362 - val_loss: 0.1097 - val_accuracy: 0.9635 - val_precision: 0.9669 - val_recall: 0.9862
# Epoch 4/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1529 - accuracy: 0.9418 - precision: 0.9832 - recall: 0.9368 - val_loss: 0.1322 - val_accuracy: 0.9548 - val_precision: 0.9896 - val_recall: 0.9512
# Epoch 5/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1312 - accuracy: 0.9495 - precision: 0.9888 - recall: 0.9422 - val_loss: 0.1162 - val_accuracy: 0.9587 - val_precision: 0.9847 - val_recall: 0.9614
# Epoch 6/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1326 - accuracy: 0.9502 - precision: 0.9858 - recall: 0.9460 - val_loss: 0.1002 - val_accuracy: 0.9606 - val_precision: 0.9566 - val_recall: 0.9937
# Epoch 7/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1571 - accuracy: 0.9399 - precision: 0.9815 - recall: 0.9358 - val_loss: 0.1292 - val_accuracy: 0.9558 - val_precision: 0.9499 - val_recall: 0.9950
# Epoch 8/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1366 - accuracy: 0.9464 - precision: 0.9857 - recall: 0.9408 - val_loss: 0.8667 - val_accuracy: 0.7731 - val_precision: 0.7720 - val_recall: 1.0000
# Epoch 9/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1252 - accuracy: 0.9516 - precision: 0.9874 - recall: 0.9461 - val_loss: 0.2042 - val_accuracy: 0.9269 - val_precision: 0.9986 - val_recall: 0.9061
# Epoch 10/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1232 - accuracy: 0.9579 - precision: 0.9866 - recall: 0.9558 - val_loss: 0.0671 - val_accuracy: 0.9760 - val_precision: 0.9899 - val_recall: 0.9787
# Epoch 11/25
# 261/261 [==============================] - 21s 82ms/step - loss: 0.1318 - accuracy: 0.9552 - precision: 0.9875 - recall: 0.9511 - val_loss: 0.1047 - val_accuracy: 0.9596 - val_precision: 0.9690 - val_recall: 0.9787
# Epoch 12/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.1245 - accuracy: 0.9555 - precision: 0.9846 - recall: 0.9544 - val_loss: 0.4755 - val_accuracy: 0.8394 - val_precision: 1.0000 - val_recall: 0.7907
# Epoch 13/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1309 - accuracy: 0.9519 - precision: 0.9867 - recall: 0.9471 - val_loss: 0.0700 - val_accuracy: 0.9740 - val_precision: 0.9742 - val_recall: 0.9925
# Epoch 14/25
# 261/261 [==============================] - 21s 82ms/step - loss: 0.1008 - accuracy: 0.9600 - precision: 0.9899 - recall: 0.9555 - val_loss: 0.0644 - val_accuracy: 0.9779 - val_precision: 0.9962 - val_recall: 0.9750
# Epoch 15/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0992 - accuracy: 0.9660 - precision: 0.9923 - recall: 0.9612 - val_loss: 0.1230 - val_accuracy: 0.9510 - val_precision: 0.9934 - val_recall: 0.9425
# Epoch 16/25
# 261/261 [==============================] - 23s 86ms/step - loss: 0.0818 - accuracy: 0.9684 - precision: 0.9901 - recall: 0.9670 - val_loss: 0.0819 - val_accuracy: 0.9692 - val_precision: 0.9886 - val_recall: 0.9713
# Epoch 17/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.0980 - accuracy: 0.9646 - precision: 0.9912 - recall: 0.9602 - val_loss: 0.0569 - val_accuracy: 0.9779 - val_precision: 0.9838 - val_recall: 0.9875
# Epoch 18/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.0902 - accuracy: 0.9658 - precision: 0.9910 - recall: 0.9623 - val_loss: 0.0635 - val_accuracy: 0.9740 - val_precision: 0.9949 - val_recall: 0.9712
# Epoch 19/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.1114 - accuracy: 0.9614 - precision: 0.9896 - recall: 0.9576 - val_loss: 0.0580 - val_accuracy: 0.9769 - val_precision: 0.9924 - val_recall: 0.9775
# Epoch 20/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.0864 - accuracy: 0.9655 - precision: 0.9913 - recall: 0.9617 - val_loss: 0.0620 - val_accuracy: 0.9798 - val_precision: 0.9838 - val_recall: 0.9900
# Epoch 21/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0792 - accuracy: 0.9686 - precision: 0.9929 - recall: 0.9640 - val_loss: 0.0591 - val_accuracy: 0.9740 - val_precision: 0.9886 - val_recall: 0.9775
# Epoch 22/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0642 - accuracy: 0.9768 - precision: 0.9953 - recall: 0.9730 - val_loss: 0.0798 - val_accuracy: 0.9721 - val_precision: 0.9707 - val_recall: 0.9937
# Epoch 23/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0703 - accuracy: 0.9753 - precision: 0.9947 - recall: 0.9716 - val_loss: 0.0697 - val_accuracy: 0.9740 - val_precision: 0.9936 - val_recall: 0.9725
# Epoch 24/25
# 261/261 [==============================] - 22s 84ms/step - loss: 0.0736 - accuracy: 0.9722 - precision: 0.9927 - recall: 0.9696 - val_loss: 0.0762 - val_accuracy: 0.9760 - val_precision: 0.9778 - val_recall: 0.9912
# Epoch 25/25
# 261/261 [==============================] - 22s 83ms/step - loss: 0.0630 - accuracy: 0.9758 - precision: 0.9950 - recall: 0.9719 - val_loss: 0.0622 - val_accuracy: 0.9760 - val_precision: 0.9778 - val_recall: 0.9912

# %% [markdown]
# ## Evaluate

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 56ms/step - loss: 0.7709 - accuracy: 0.8093 - precision: 0.7737 - recall: 0.9821

# %%
loss, acc, prec, rec = model_aug.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 55ms/step - loss: 0.8587 - accuracy: 0.8141 - precision: 0.7740 - recall: 0.9923

# %%
loss, acc, prec, rec = model_drop_half.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 55ms/step - loss: 0.7513 - accuracy: 0.8510 - precision: 0.8207 - recall: 0.9744

# %%
loss, acc, prec, rec = model_no_drop.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 54ms/step - loss: 1.5179 - accuracy: 0.7484 - precision: 0.7138 - recall: 0.9974

# %% [markdown]
# ## visualization

# %% [markdown]
# ### baseline model

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### augmentation model

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history_aug.history[met])
    ax[i].plot(history_aug.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['aug_train', 'aug_val'])

# %% [markdown]
# ### drop out half model

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history_drop_half.history[met])
    ax[i].plot(history_drop_half.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['drop_half_train', 'drop_half_val'])

# %% [markdown]
# ### except drop out model

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history_no_drop.history[met])
    ax[i].plot(history_no_drop.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['no_drop_train', 'no_drop_val'])

# %% [markdown]
# ## Report

# %% [markdown]
# Model accuracy가 Drop out을 반만 적용한 모델이 가장 높았다. Recall이 높게 측정 된 것은 augmentation한 모델과 Dropout을 없앤
#
# 모델이다. 전체 모델들 전반적으로 validation에서 그래프가 안정적이지 못한 것 같다.
#
# 모델 자체를 변경해보는 것도 좋지만, 데이터를 추가하거나 weight 조정을 잘 해야할 것 같다.
