# %% [markdown]
# ## import

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

import copy
import cv2
from PIL import Image

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## data

# %%
import urllib3
urllib3.disable_warnings()
(ds_train, ds_test), ds_info = tfds.load(
    'cars196',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
def normalize_and_resize_img(input):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(input['image'], [224, 224])
    input['image'] = tf.cast(image, tf.float32) / 255.
    return input['image'], input['label']

def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=2
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %%
ds_train_norm = apply_normalize_on_dataset(ds_train)
ds_test_norm = apply_normalize_on_dataset(ds_test)

# %%
def get_one(ds):
    ds = ds.take(1)
    sample_data = list(ds.as_numpy_iterator())
    bbox = sample_data[0]['bbox']
    image = sample_data[0]['image']
    label = sample_data[0]['label']
    return sample_data[0]

# %% [markdown]
# ## Model

# %%
num_classes = ds_info.features["label"].num_classes
base_model = keras.applications.resnet.ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=(224, 224,3),
    pooling='avg',
)
x = base_model.output
preds = keras.layers.Dense(num_classes, activation = 'softmax')(x)
cam_model=keras.Model(inputs=base_model.input, outputs=preds)

# %%
tf.random.set_seed(2020)
cam_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(lr=0.01),
    metrics=['accuracy'],
)

# %%
history_cam_model = cam_model.fit(
    ds_train_norm,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=15,
    validation_data=ds_test_norm,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/15
#   2/509 [..............................] - ETA: 36s - loss: 5.3917 - accuracy: 0.0312   WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0563s vs `on_train_batch_end` time: 0.0874s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0563s vs `on_train_batch_end` time: 0.0874s). Check your callbacks.
# 509/509 [==============================] - 89s 176ms/step - loss: 4.1132 - accuracy: 0.1682 - val_loss: 5.4193 - val_accuracy: 0.0062
# Epoch 2/15
# 509/509 [==============================] - 80s 157ms/step - loss: 1.6069 - accuracy: 0.6494 - val_loss: 1.8592 - val_accuracy: 0.5300
# Epoch 3/15
# 509/509 [==============================] - 80s 157ms/step - loss: 0.5804 - accuracy: 0.8969 - val_loss: 1.2641 - val_accuracy: 0.6708
# Epoch 4/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.1856 - accuracy: 0.9795 - val_loss: 1.0498 - val_accuracy: 0.7207
# Epoch 5/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0719 - accuracy: 0.9961 - val_loss: 0.9803 - val_accuracy: 0.7335
# Epoch 6/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0339 - accuracy: 0.9984 - val_loss: 0.9756 - val_accuracy: 0.7374
# Epoch 7/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0267 - accuracy: 0.9986 - val_loss: 0.9820 - val_accuracy: 0.7362
# Epoch 8/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0215 - accuracy: 0.9985 - val_loss: 0.9586 - val_accuracy: 0.7418
# Epoch 9/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0177 - accuracy: 0.9994 - val_loss: 0.9494 - val_accuracy: 0.7461
# Epoch 10/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0145 - accuracy: 0.9990 - val_loss: 0.9535 - val_accuracy: 0.7491
# Epoch 11/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0120 - accuracy: 0.9995 - val_loss: 0.9546 - val_accuracy: 0.7456
# Epoch 12/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0139 - accuracy: 0.9990 - val_loss: 0.9647 - val_accuracy: 0.7474
# Epoch 13/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0101 - accuracy: 0.9989 - val_loss: 0.9749 - val_accuracy: 0.7438
# Epoch 14/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0076 - accuracy: 0.9996 - val_loss: 0.9661 - val_accuracy: 0.7455
# Epoch 15/15
# 509/509 [==============================] - 80s 158ms/step - loss: 0.0060 - accuracy: 0.9998 - val_loss: 0.9664 - val_accuracy: 0.7456

# %% [markdown]
# ## Model Save & Load

# %%
import os

cam_model_path = os.getenv('HOME')+'/aiffel/class_activation_map/cam_model.h5'
cam_model.save(cam_model_path)

# %%
cam_model = tf.keras.models.load_model(cam_model_path)

# %% [markdown]
# # CAM 구현

# %%
def generate_cam(model, item):
    item = copy.deepcopy(item)
    width = item['image'].shape[1]
    height = item['image'].shape[0]
    
    img_tensor, class_idx = normalize_and_resize_img(item)
    cam_model = tf.keras.models.Model([model.inputs], [model.layers[-3].output, model.output])
    conv_outputs, predictions = cam_model(tf.expand_dims(img_tensor, 0))
    
    conv_outputs = conv_outputs[0, :, :, :]
    class_weights = model.layers[-1].get_weights()[0]
    
    cam_image = np.zeros(dtype=np.float32, shape=conv_outputs.shape[0:2])
    for i, w in enumerate(class_weights[:, class_idx]):
        cam_image += w * conv_outputs[:, :, i]

    cam_image /= np.max(cam_image)
    cam_image = cam_image.numpy()
    cam_image = cv2.resize(cam_image, (width, height))
    return cam_image

# %%
item = get_one(ds_test)
print(item['label'])
plt.imshow(item['image'])
print(item['image'].shape)
# Out:
# 116
# (360, 480, 3)

# %%
cam_image = generate_cam(cam_model, item)
plt.imshow(cam_image)

# %%
def visualize_cam_on_image(src1, src2, alpha=0.7):
    beta = (1.0 - alpha)	
    merged_image = cv2.addWeighted(src1, alpha, src2, beta, 0.0)
    return merged_image

# %%
origin_image = item['image'].astype(np.uint8)
cam_image_3channel = np.stack([cam_image*255]*3, axis=-1).astype(np.uint8)

blended_image = visualize_cam_on_image(cam_image_3channel, origin_image)
plt.imshow(blended_image)

# %%
def generate_grad_cam(model, activation_layer, item):
    item = copy.deepcopy(item)
    width = item['image'].shape[1]
    height = item['image'].shape[0]
    img_tensor, class_idx = normalize_and_resize_img(item)

    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(activation_layer).output, model.output])
    
    with tf.GradientTape() as tape:
        conv_output, pred = grad_model(tf.expand_dims(img_tensor, 0))
    
        loss = pred[:, class_idx]
        output = conv_output[0]
        grad_val = tape.gradient(loss, conv_output)[0] 

    weights = np.mean(grad_val, axis=(0, 1)) 
    grad_cam_image = np.zeros(dtype=np.float32, shape=conv_output.shape[0:2])
    for k, w in enumerate(weights):
        grad_cam_image += w * output[:, :, k]
        
    grad_cam_image /= np.max(grad_cam_image)
    grad_cam_image = grad_cam_image.numpy()
    grad_cam_image = cv2.resize(grad_cam_image, (width, height))
    return grad_cam_image

# %%
item = get_one(ds_test)
print(item['label'])
plt.imshow(item['image'])
print(item['image'].shape)
# Out:
# 120
# (225, 300, 3)

# %%
grad_cam_image = generate_grad_cam(cam_model, 'conv5_block3_out', item)
plt.imshow(grad_cam_image)

# %%
origin_image = item['image'].astype(np.uint8)
grad_cam_image_3channel = np.stack([grad_cam_image*255]*3, axis=-1).astype(np.uint8)

blended_image = visualize_cam_on_image(grad_cam_image_3channel, origin_image)
plt.imshow(blended_image)

# %%
grad_cam_image = generate_grad_cam(cam_model, 'conv4_block3_out', item)
plt.imshow(grad_cam_image)

# %%
origin_image = item['image'].astype(np.uint8)
grad_cam_image_3channel = np.stack([grad_cam_image*255]*3, axis=-1).astype(np.uint8)

blended_image = visualize_cam_on_image(grad_cam_image_3channel, origin_image)
plt.imshow(blended_image)

# %%
grad_cam_image = generate_grad_cam(cam_model, 'conv3_block3_out', item)
plt.imshow(grad_cam_image)

# %%
origin_image = item['image'].astype(np.uint8)
grad_cam_image_3channel = np.stack([grad_cam_image*255]*3, axis=-1).astype(np.uint8)

blended_image = visualize_cam_on_image(grad_cam_image_3channel, origin_image)
plt.imshow(blended_image)

# %% [markdown]
# ## Detection witch CAM

# %%
item = get_one(ds_test)
print(item['label'])
plt.imshow(item['image'])
# Out:
# 141

# %%
cam_image = generate_cam(cam_model, item)
plt.imshow(cam_image)

# %%
grad_cam_image = generate_grad_cam(cam_model, 'conv5_block3_out', item)
plt.imshow(grad_cam_image)

# %%
def get_bbox(cam_image, score_thresh=0.05):
    low_indicies = cam_image <= score_thresh
    cam_image[low_indicies] = 0
    cam_image = (cam_image*255).astype(np.uint8)
    
    contours,_ = cv2.findContours(cam_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cnt = contours[0]
    rotated_rect = cv2.minAreaRect(cnt)
    rect = cv2.boxPoints(rotated_rect)
    rect = np.int0(rect)
    return rect

# %%
image = copy.deepcopy(item['image'])
rect = get_bbox(cam_image)
image = cv2.drawContours(image,[rect],0,(0,0,255),2)
plt.imshow(image)

# %%
image = copy.deepcopy(item['image'])
grad_cam_rect = get_bbox(grad_cam_image)
grad_cam_image = cv2.drawContours(image,[grad_cam_rect],0,(0,0,255),2)
plt.imshow(grad_cam_image)

# %%
# rect의 좌표는 (x, y) 형태로, bbox는 (y_min, x_min, y_max, x_max)의 normalized 형태로 주어집니다. 
def rect_to_minmax(rect, image):
    bbox = [
        rect[:,1].min()/float(image.shape[0]),  #bounding box의 y_min
        rect[:,0].min()/float(image.shape[1]),  #bounding box의 x_min
        rect[:,1].max()/float(image.shape[0]), #bounding box의 y_max
        rect[:,0].max()/float(image.shape[1]) #bounding box의 x_max
    ]
    return bbox

# %%
pred_bbox = rect_to_minmax(rect, item['image'])
pred_bbox
# Out:
# [0.36338028169014086,
#  0.10896309314586995,
#  0.9126760563380282,
#  0.8963093145869947]

# %%
grad_cam_pred_bbox = rect_to_minmax(grad_cam_rect, item['image'])
grad_cam_pred_bbox
# Out:
# [0.36619718309859156,
#  0.15114235500878734,
#  0.923943661971831,
#  0.9015817223198594]

# %%
item['bbox']
# Out:
# array([0.35211268, 0.16695958, 0.8197183 , 0.7557118 ], dtype=float32)

# %%
def get_iou(boxA, boxB):
    y_min = max(boxA[0], boxB[0])
    x_min= max(boxA[1], boxB[1])
    y_max = min(boxA[2], boxB[2])
    x_max = min(boxA[3], boxB[3])
    
    interArea = max(0, x_max - x_min) * max(0, y_max - y_min)
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    iou = interArea / float(boxAArea + boxBArea - interArea)

    return iou

# %%
get_iou(pred_bbox, item['bbox'])
# Out:
# 0.6118376636967491

# %%
get_iou(grad_cam_pred_bbox, item['bbox'])
# Out:
# 0.6255436699897341
